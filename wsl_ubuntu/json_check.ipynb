# %%
import pandas as pd
import numpy as np
import json

# %%
with open('output/batch_test_output.json') as f:
    data_10 = json.load(f)

# %%
df = pd.read_json("output/batch_test_output.json") 
print(df.head())
# Out:
#       CID                                             smiles  \
# 0  BACE_1  O1CC[C@@H](NC(=O)[C@@H](Cc2cc3cc(ccc3nc2N)-c2c...
# 1  BACE_2  Fc1cc(cc(F)c1)C[C@H](NC(=O)[C@@H](N1CC[C@](NC(...
# 2  BACE_3  S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...
# 3  BACE_4  S1(=O)(=O)C[C@@H](Cc2cc(O[C@H](COCC)C(F)(F)F)c...
# 4  BACE_5  S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...
#
#                                          description  \
# 0  Based on the provided SMILES notation, molecul...
# 1  Based on the provided chemical descriptors, th...
# 2  Based on the provided chemical descriptors, th...
# 3  Based on the provided molecular descriptors, t...
# 4  Based on the provided chemical descriptors, th...
#
#                                            embedding
# 0  [-0.023948056623339, -0.015201174654066, -0.00...
# 1  [-0.0014392815064630002, -0.021227424964308003...
# 2  [-0.013580067083239, -0.005350184161216001, -0...
# 3  [-0.0019066026434300001, -0.029275430366396002...
# ...

# %%
des = df['description'][1]
print(f"```{des}```")
# Out:
# ```
# Based on the provided chemical descriptors, this molecule appears to possess moderate to high drug-likeness, with a molecular weight of approximately 658 g/mol, an AlogP value of 2.64 indicating sufficient lipophilicity for membrane permeability, and a pIC50 value of 8.85 suggesting potent biological activity. The presence of aromatic rings, heterocyclic compounds, and ester functional groups suggests a potential for oral bioavailability and interaction with biologically relevant targets, warranting further investigation into its pharmacological properties and therapeutic potential.
# ```

# %%
import json

path = "/home/yl9210a-hpc/chem_project/llama_cluster/output/final_bace_with_embeddings.json"

with open(path, "r") as f:
    data = json.load(f)

print("Total entries:", len(data))
print("First entry keys:", data[0].keys())
print("Example entry:", data[0])
